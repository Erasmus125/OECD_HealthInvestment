# %% [markdown]
# <a href="https://colab.research.google.com/github/Erasmus125/NexValli-Project/blob/main/hlthinvest.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-6536db26-5c76-44d2-82d9-c59c1f97f6c7" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6536db26-5c76-44d2-82d9-c59c1f97f6c7">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd

# %%
import io
df=pd.read_csv(io.BytesIO(uploaded['hlthinvest.csv']))

# %%
df.head()
# Out:
#   Countrycode    Country  Year  Hospital_Stay  MRI_Units  CT_Scanners  \
# 0         AUS  Australia  1992            6.6       1.43        16.71
# 1         AUS  Australia  1994            6.4       2.36        18.48
# 2         AUS  Australia  1995            6.5       2.89        20.55
# 3         AUS  Australia  1996            6.4       2.96        21.95
# 4         AUS  Australia  1997            6.2       3.53        23.34
#
#    Hospital_Beds
# 0           1.43
# 1           2.36
# 2           2.89
# 3           2.96
# 4           3.53

# %%
display(df.min())
# Out:
# Countrycode            AUS
# Country          Australia
# Year                  1990
# Hospital_Stay          3.4
# MRI_Units              0.1
# CT_Scanners           1.48
# Hospital_Beds          0.1
# dtype: object

# %%
df.shape
# Out:
# (518, 7)

# %%
display(df.max())
# Out:
# Countrycode                USA
# Country          United States
# Year                      2018
# Hospital_Stay             32.7
# MRI_Units                55.21
# CT_Scanners             111.49
# Hospital_Beds            55.21
# dtype: object

# %%
display(df.max())
# Out:
# Countrycode                USA
# Country          United States
# Year                      2018
# Hospital_Stay             32.7
# MRI_Units                55.21
# CT_Scanners             111.49
# Hospital_Beds            55.21
# dtype: object

# %%
display()

# %%
max_mri_by_country_year = df.groupby(['Country', 'Year'])['MRI_Units'].max()
display(max_mri_by_country_year)
# Out:
# Country        Year
# Australia      1992     1.43
#                1994     2.36
#                1995     2.89
#                1996     2.96
#                1997     3.53
#                        ...
# United States  2013    35.51
#                2014    38.12
#                2015    39.03
#                2016    36.74
#                2017    37.65
# Name: MRI_Units, Length: 518, dtype: float64

# %%
max_mri_by_country_year = df.groupby(['Country', 'Year'])['MRI_Units'].max()
display(max_mri_by_country_year)

# %%
1+2=
# Out:
#   File "/tmp/ipython-input-3282634048.py", line 1
#     1+2=
#     ^
# SyntaxError: cannot assign to expression

# %%
type(MRI_Units)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-267095704.py in <cell line: 0>()
# ----> 1 type(MRI_Units)
#
# NameError: name 'MRI_Units' is not defined
